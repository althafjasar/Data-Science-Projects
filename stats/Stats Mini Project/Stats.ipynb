# %%
## CALLING LIBRARIES
import numpy             as np
import pandas            as pd
import scipy.stats       as stats
import matplotlib.pyplot as plt
# %matplotlib inline
import seaborn           as sns
import math

# %% [markdown]
# # Question 1

# %%
Lalig=pd.read_csv("Laliga.csv")

# %%
Lalig
# Out:
#     Pos                 Team  Seasons Points GamesPlayed GamesWon GamesDrawn  \
# 0     1          Real Madrid       86   4385        2762     1647        552
# 1     2            Barcelona       86   4262        2762     1581        573
# 2     3      Atletico Madrid       80   3442        2614     1241        598
# 3     4             Valencia       82   3386        2664     1187        616
# 4     5      Athletic Bilbao       86   3368        2762     1209        633
# 5     6              Sevilla       73   2819        2408      990        531
# 6     7             Espanyol       82   2792        2626      948        608
# 7     8        Real Sociedad       70   2573        2302      864        577
# 8     9             Zaragoza       58   2109        1986      698        522
# 9    10           Real Betis       51   1884        1728      606        440
# 10   11  Deportivo La Coruna       45   1814        1530      563        392
# ...

# %%
Lalig['Debut']=Lalig['Debut'].map(lambda x: str(x)[0:4])

# %%
Lalig['Since/LastApp']=Lalig['Since/LastApp'].map(lambda x: str(x)[0:4])

# %%
Lalig
# Out:
#     Pos                 Team  Seasons Points GamesPlayed GamesWon GamesDrawn  \
# 0     1          Real Madrid       86   4385        2762     1647        552
# 1     2            Barcelona       86   4262        2762     1581        573
# 2     3      Atletico Madrid       80   3442        2614     1241        598
# 3     4             Valencia       82   3386        2664     1187        616
# 4     5      Athletic Bilbao       86   3368        2762     1209        633
# 5     6              Sevilla       73   2819        2408      990        531
# 6     7             Espanyol       82   2792        2626      948        608
# 7     8        Real Sociedad       70   2573        2302      864        577
# 8     9             Zaragoza       58   2109        1986      698        522
# 9    10           Real Betis       51   1884        1728      606        440
# 10   11  Deportivo La Coruna       45   1814        1530      563        392
# ...

# %%
Lalig.replace('-',np.nan,inplace=True)

# %%
Lalig['Debut']=Lalig['Debut'].astype(int)

# %%
Lalig
# Out:
#     Pos                 Team  Seasons Points GamesPlayed GamesWon GamesDrawn  \
# 0     1          Real Madrid       86   4385        2762     1647        552
# 1     2            Barcelona       86   4262        2762     1581        573
# 2     3      Atletico Madrid       80   3442        2614     1241        598
# 3     4             Valencia       82   3386        2664     1187        616
# 4     5      Athletic Bilbao       86   3368        2762     1209        633
# 5     6              Sevilla       73   2819        2408      990        531
# 6     7             Espanyol       82   2792        2626      948        608
# 7     8        Real Sociedad       70   2573        2302      864        577
# 8     9             Zaragoza       58   2109        1986      698        522
# 9    10           Real Betis       51   1884        1728      606        440
# 10   11  Deportivo La Coruna       45   1814        1530      563        392
# ...

# %%
Lalig.describe()
# Out:
#              Pos    Seasons        Debut  BestPosition
# count  61.000000  61.000000    61.000000     61.000000
# mean   31.000000  24.000000  1958.918033      7.081967
# std    17.752934  26.827225    27.484114      5.276663
# min     1.000000   1.000000  1929.000000      1.000000
# 25%    16.000000   4.000000  1935.000000      3.000000
# 50%    31.000000  12.000000  1951.000000      6.000000
# 75%    46.000000  38.000000  1978.000000     10.000000
# max    61.000000  86.000000  2017.000000     20.000000

# %%
Lalig.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 61 entries, 0 to 60
# Data columns (total 20 columns):
# Pos              61 non-null int64
# Team             61 non-null object
# Seasons          61 non-null int64
# Points           60 non-null object
# GamesPlayed      60 non-null object
# GamesWon         60 non-null object
# GamesDrawn       60 non-null object
# GamesLost        60 non-null object
# GoalsFor         60 non-null object
# GoalsAgainst     60 non-null object
# Champion         9 non-null object
# Runner-up        13 non-null object
# Third            18 non-null object
# Fourth           22 non-null object
# Fifth            25 non-null object
# Sixth            28 non-null object
# T                33 non-null object
# Debut            61 non-null int32
# Since/LastApp    61 non-null object
# BestPosition     61 non-null int64
# dtypes: int32(1), int64(3), object(16)
# memory usage: 9.4+ KB

# %% [markdown]
# # 1.1.	Which are the teams which started playing between 1930-1980?

# %%
Lalig[(Lalig['Debut']>=1930) & (Lalig['Debut']<=1980)].loc[:,['Team','Debut']]
# Out:
#                    Team  Debut
# 3              Valencia   1931
# 5               Sevilla   1934
# 8              Zaragoza   1939
# 9            Real Betis   1932
# 10  Deportivo La Coruna   1941
# 11           Celta Vigo   1939
# 12           Valladolid   1948
# 14       Sporting Gijon   1944
# 15              Osasuna   1935
# 16               Malaga   1949
# 17               Oviedo   1933
# 18             Mallorca   1960
# 19           Las Palmas   1951
# 21              Granada   1941
# 22       Rayo Vallecano   1977
# 23                Elche   1959
# 25             Hercules   1935
# 26             Tenerife   1961
# 27               Murcia   1940
# 28               Alaves   1930
# 29              Levante   1963
# 30            Salamanca   1974
# 31             Sabadell   1943
# 32                Cadiz   1977
# 34            Castellon   1941
# 37              Cordoba   1962
# 39           Recreativo   1978
# 40            Burgos CF   1971
# 41           Pontevedra   1963
# ...

# %% [markdown]
# # 2.	Which are the top 5 teams in terms of points?

# %%
Lalig['Points']=Lalig['Points'].astype(float)

# %%
Lalig.sort_values('Points',ascending=False,inplace=True)
Lalig.head().loc[:,['Team','Points']]
# Out:
#               Team  Points
# 0      Real Madrid  4385.0
# 1        Barcelona  4262.0
# 2  Atletico Madrid  3442.0
# 3         Valencia  3386.0
# 4  Athletic Bilbao  3368.0

# %% [markdown]
# # 3.	What is the distribution of the winning percentage for all teams? Which teams are in the top 5 in terms of winning percentage? (Winning percentage= (GamesWon / GamesPlayed)*100)

# %%
Lalig['GamesWon']=Lalig['GamesWon'].astype(float)
Lalig['GamesPlayed']=Lalig['GamesPlayed'].astype(float)

# %%
Lalig['WinningPercentage']=(Lalig['GamesWon']/Lalig['GamesPlayed'])*100

# %%
Lalig.sort_values('WinningPercentage',ascending=False,inplace=True)
Lalig.loc[:,['Team','WinningPercentage']]
# Out:
#                    Team  WinningPercentage
# 0           Real Madrid          59.630702
# 1             Barcelona          57.241130
# 2       Atletico Madrid          47.475134
# 3              Valencia          44.557057
# 4       Athletic Bilbao          43.772629
# 20           Villarreal          41.176471
# 5               Sevilla          41.112957
# 7         Real Sociedad          37.532580
# 10  Deportivo La Coruna          36.797386
# 6              Espanyol          36.100533
# 8              Zaragoza          35.146022
# 9            Real Betis          35.069444
# 11           Celta Vigo          34.511190
# 17               Oviedo          34.228188
# 18             Mallorca          33.704453
# 19           Las Palmas          33.485401
# 53               Europa          33.333333
# 44               Arenas          33.076923
# 28               Alaves          32.894737
# 38           Compostela          32.500000
# 15              Osasuna          32.321700
# ...

# %%
plt.subplots(figsize=(18,15))
sns.barplot(y=Lalig['Team'],x=Lalig['WinningPercentage'])

# %% [markdown]
# # 4.	Is there a significant difference in the winning percentage for teams which have attained a best position between 1-3 and those teams which have had a best position between 4-7.

# %%
Lalig['BestPosition']=Lalig['BestPosition'].astype(int)

# %%
top3=Lalig[(Lalig['BestPosition']>=1) & (Lalig['BestPosition']<=3)]

# %%
top3['WinningPercentage'].mean()
# Out:
# 39.67412368466111

# %%
top37=top3=Lalig[(Lalig['BestPosition']>=4) & (Lalig['BestPosition']<=7)]

# %%
top37['WinningPercentage'].mean()
# Out:
# 30.291020220767212

# %% [markdown]
# # Question 2

# %% [markdown]
# # a)	Calculate the estimated standard error of the sample mean? What does the standard error indicate?

# %%
mu=140
sigma=25
n=200

# %%
see=sigma/n**0.5

# %%
see
# Out:
# 1.7677669529663687

# %% [raw]
# observation:1.76 is the deviation of mean of sample from the population mean

# %% [markdown]
# # b)	Estimate a 95% confidence interval for the true mean blood pressure for all 60-year old women with glaucoma.

# %%
ci=0.95
lw,rw=stats.norm.interval(0.95,mu,see)

# %%
lw
# Out:
# 136.5352404391258

# %%
rw
# Out:
# 143.4647595608742

# %% [markdown]
# # c)	Assume that instead of 200, a random sample of only 100 60-year old women with glaucoma was chosen. The sample mean and standard deviation estimates are the same as those in the original study. What is the estimated 95% confidence interval for the true mean blood pressure?

# %%
n1=100
newse=sigma/n1**0.5
lw,rw=stats.norm.interval(0.95,mu,newse)

# %%
lw
# Out:
# 135.10009003864985

# %%
rw
# Out:
# 144.89990996135015

# %% [markdown]
# # d)	Which of the two above intervals are wider?

# %% [raw]
# sample size n=100 has wider intervals.

# %% [markdown]
# # e)	Explain in non-technical terms why the estimated standard error of a sample mean tends to decrease with an increase in sample size.

# %%
newse
# Out:
# 2.5

# %% [raw]
# when sample size increases the devation from sample mean decreases

# %% [markdown]
# # Question 3

# %%
golf=pd.read_csv("Golf.csv")

# %%
golf.describe()
# Out:
#           Current         New
# count   40.000000   40.000000
# mean   270.275000  267.500000
# std      8.752985    9.896904
# min    255.000000  250.000000
# 25%    263.000000  262.000000
# 50%    270.000000  265.000000
# 75%    275.250000  274.500000
# max    289.000000  289.000000

# %% [markdown]
# # 1.	Formulate and present the rationale for a hypothesis test that Par could use to compare the driving distances of the current and new golf balls.

# %% [raw]
# since the sample is normaly distributed we can go for the unpaired t test to determine wheather new ball is performing better than old

# %% [markdown]
# # 2.	Analyze the data to provide the hypothesis testing conclusion. What is the p-value for your test? What is your recommendation for Par Inc.?

# %% [raw]
# # Ho->uc=un
# Hi->uc!=un

# %%
t,p=stats.ttest_ind(golf['Current'],golf['New'])

# %%
p
# Out:
# 0.18793228491854663

# %%
t
# Out:
# 1.3283615935245678

# %%
stats.t.isf(0.05,39)
# Out:
# 1.6848751194974

# %% [markdown]
# # 3.	What is the 95% confidence interval for the population mean of each model, and what is the 95% confidence interval for the difference between the means of the two population?

# %%
meancurre=golf['Current'].mean()

# %%
meannew=golf['New'].mean()

# %%
stdcurr=golf['Current'].std()
stdnew=golf['New'].std()
n=40
seec=stdcurr/n**0.5
seen=stdnew/n**0.5

# %%
seec
# Out:
# 1.383968420789864

# %%
seen
# Out:
# 1.5648379944000428

# %%
#interval of current
lw,up=stats.norm.interval(0.95,meancurre,seec)

# %%
lw
# Out:
# 267.56247173951107

# %%
up
# Out:
# 272.9875282604889

# %%
#interval of new

# %%
lwn,upn=stats.norm.interval(0.95,meannew,seen)

# %%
lwn
# Out:
# 264.43297388933604

# %%
upn
# Out:
# 270.56702611066396

# %%
#difference of two mean

# %%
sdofmeandiff=((stdcurr)**2/n + (stdnew)**2/n)**0.5

# %%
sdofmeandiff
# Out:
# 2.08903962108466

# %%
sdofmeandiff
# Out:
# 2.08903962108466

# %%
z=stats.norm.isf(q=0.05/2)

# %%
lwfordiff=z*sdofmeandiff #isf

# %%
lwfordiff
# Out:
# 4.094442419603135

# %%
diffmean=meancurre-meannew

# %%
uw=diffmean+lwfordiff

# %%
lw=diffmean-lwfordiff

# %%
#interval of difference of mean

# %%
print("interval({},{})".format(lw,uw))
# Out:
# interval(-1.319442419603158,6.8694424196031125)

# %%
sigma=((stdcurr**2/n)+(stdnew**2/n))**0.5
Lower_Interval = abs(meancurre-meannew) - (z * (sigma))
Upper_Interval = abs(meancurre-meannew) + (z * (sigma))

Lower_Interval,Upper_Interval
# Out:
# (-1.319442419603158, 6.8694424196031125)
